# %% [markdown]
# # Automated Coulomb Barrier Search - Google Colab

# %% [markdown]
# ## 1. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Clone the Repository & Install Dependencies

# %%
# !if [ -d "/content/Coulomb-Barrier-Search" ]; then cd /content/Coulomb-Barrier-Search && git fetch origin && git reset --hard origin/main; else git clone https://github.com/mnejmi/Coulomb-Barrier-Search.git /content/Coulomb-Barrier-Search; fi
# %cd /content/Coulomb-Barrier-Search
# !pip install pytorch-lightning

# %% [markdown]
# ## 3. Run the Barrier Search

# %%
# !python3 run_barrier_search.py \
    --model_dir local_data/UNO_Transformer_v7_ultimate_dev \
    --ckpt "/content/drive/MyDrive/PHD/UNO_Checkpoints/Iter4_Model/last.ckpt" \
    --data_dir local_data \
    --traj local_data/40Ca_90Zr_92.pt \
    --ecm_min 40.0 \
    --ecm_max 120.0 \
    --n_step 60
